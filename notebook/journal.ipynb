# %% [markdown]
# # Linux Related
#
# ## 文本权限，通配符和环境变量
# ### 文本权限
# `ls -l`: 第1个字母表示directory/文件，第2-10个数字三个为一组分别表示user，group和others的权限（w:write, r:read, x:executable）\
# `chmod u+/-w`: change mode, user +/- write
#
# ## 创建和删除venv
# 创建venv_name: `python -m venv venv_name`\
# 删除venv_name: `sudo rm -rf venv_name`
#
# ## 常用命令
# * remove the directory which is not empty:
# `rmdir -rf dir_name`
#
# * read the python file in the terminal:
# `vim file_name.py`

# %% [markdown]
# # VSCode related
#
# [useful tips](https://juejin.cn/post/6844903826063884296#heading-55)
#
# ## Configuration setting
# **Set the `working directory:`**
# 1. `setting` &rarr; `command pallete`
# 2. search the launch.json file
# 3. add `"cwd": "${fileDirname}"` in configurations
# 4. the defalt file working directory is one layer above
#
# ## short cuts:
# command + /: annotation
#
# ## Tips
# * change interpreter \
# `command + shift + p` &rarr; change interpreter \
#
# `option + shift + a`: docstring \
# `command + /`: commnet

# %% [markdown]
# # Anaconda
# ## [generate the new environment](https://zhuanlan.zhihu.com/p/108506007)
# `conda create --name myenv_conda` \
# `conda activate myenv_conda` \
# `conda deactivate`
#
# `conda list`:查看已安装包
#
# `conda info --env`: check existing environment \
# `conda env remove -n py310`: remove environment \
#
# ## base升级python3.10一直不成功 [Solution](https://exerror.com/solving-environment-failed-with-initial-frozen-solve-retrying-with-flexible-solve/):
# `conda create --name myenv` \
# `conda activate myenv` \
# `conda config --set chan nel_priority false` \
# `conda install -n py310 python=3.10` \
# `conda update --all --yes`
#
# ## conda 常用语句
# ![IMG_0160.JPG](attachment:IMG_0160.JPG)

# %% [markdown]
# # R related
# ## update R
# `install.packages('devtools') #assuming it is not already installed
# library(devtools)
# install_github('andreacirilloac/updateR')
# library(updateR)
# updateR(admin_password = 'Admin user password')
# `

# %% [markdown]
# # Python related
# ## PyCharm
# Before you run the code in the PyCharm IDE, make sure the edit `configuration` is set beforehand.
#
# **Notice**
# + do not use the module names as the name of the files, like do not name numpy.py etc.

# %% [markdown]
# # ShortCuts:
# ## [jupyter notebook shortcuts](https://towardsdatascience.com/jypyter-notebook-shortcuts-bf0101a98330)
#
# - a: above cell
# - b: bellow cell
# - x: cut cell
# - y: change cell type to *code*
# - m: change cell type to markdown
# - press "d" twice to delete the cell
# - 在单独的标题cell中 `esc` + `数字`： 直接调整标题极数
#
# ## Chrom 浏览器
# - `command + shift + 1,2,3...`：跳转到第几个页面
# - `command + shift + T`：打开最近关闭页面
#
# ## Mac
# - 显示隐藏文件: `command+shift+.`

# %% [markdown]
# # [markdown syntax](https://rmarkdown.rstudio.com/authoring_basics.html)
# ## Arrows in markdown
# `&larr;`: &larr; left arrow \
# `&rarr;`: &rarr; right arrow \
# `&uarr;`: &uarr; up arrow \
# `&darr;`: &darr; down arrow  \
# `&harr;`: &harr; doboule headed arrow
#
# ## Itemize
# + `+` or `*`: itemize
#     * `+` or `*` sub itemise
#         * test
#
# ## Code block
# **e.g. R code block**
# ```{r}
# summary(cars$dist)
# summary(cars$speed)
# ```
# ```
# print("hello world")
# ```
#
# ## Quotations
# > Quotations
#
# ## Quotes
# one " \* " &rarr; *斜体* \
# two " \* " &rarr; **加粗** \
# three " \* " &rarr; ***斜体+加粗*** \
# use " \` " to quote `code`
#
# ## 设置几级标题
# 命令模式下空cell + 数字
#
# ## [公式](https://blog.csdn.net/smilejiasmile/article/details/80670742)
# [符号](https://www.jianshu.com/p/93ccc63e5a1b)
#
# ##  markdown里注释
# <something you will not see when you compile the cell>

# %% [markdown]
# # Tips
# ## SSH:
# set up your ssh-based protacal to connect and interact with your remote services. \
# e.g. [set git SSH](https://docs.github.com/en/authentication/connecting-to-github-with-ssh)
#
# * use `pip3` instead of `pip`
# * `python -m pip install XXX`

# %% [markdown]
# # 遇到的问题
# ## 可能是jupyter notebook编译器的问题，不能调用模块
# [解决方案](https://www.jianshu.com/p/5eed417e04ca) \
# `conda install nb_conda_kernels`
#
# ## 关于找不到[graphviz module](https://blog.csdn.net/authorized_keys/article/details/100532002) or [this](https://zhuanlan.zhihu.com/p/417012153)
#
# ## Automatically add content in the jupyter notebook:
# [install extension](https://blog.csdn.net/weixin_42150990/article/details/81081889)\
# [open/shut down it](https://www.zhihu.com/question/267934067)
