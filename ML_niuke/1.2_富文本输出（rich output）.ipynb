# %% [markdown]
# # 引入模块 display

# %%
from IPython.display import display

# %%
from IPython.display import (
    display_pretty, display_html, display_jpeg, display_png, display_json, display_latex, display_svg
)

# %% [markdown]
# # image

# %%
from IPython.display import Image

# %%
i = Image("test.jpeg")

# %%
i

# %%
display(i)

# %%
Image(url="https://images.sucaihuo.com/videos/3/321/big.jpg")
# Out:
# <img src="https://images.sucaihuo.com/videos/3/321/big.jpg"/>

# %% [markdown]
# svg 格式

# %%
from IPython.display import SVG

# %% [markdown]
# ## 嵌入式(embedded)/非嵌入式图片

# %%
from IPython.display import Image

img_url = 'https://images.sucaihuo.com/videos/3/321/big.jpg'

# 如果设定了URL参数就不会内嵌
SoftLinked = Image(url = img_url)

# 如果强制要求嵌入
ForceEmbed = Image(url = img_url, embed = True)

# %%
SoftLinked
# Out:
# <img src="https://images.sucaihuo.com/videos/3/321/big.jpg"/>

# %% [markdown]
# `%%html` \
# `%%javascript` \
# `%%latex`

# %% [markdown]
# ## 音频 audio

# %%
from IPython.display import Audio
Audio(url = "https://music.163.com/song?id=1357576404&userid=486248047")
# Out:
#                 <audio  controls="controls" >
#                     <source src="https://music.163.com/song?id=1357576404&userid=486248047" type="None" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np
max_time = 3
f1 = 220
f2 = 224
rate = 8000
L = 3
times = np.linspace(0, L, rate*L)
signal = np.sin(2*np.pi*f1*times) + np.sin(2*np.pi*f2*times)

Audio(data = signal, rate = rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 外部网站

# %%
from IPython.display import IFrame
IFrame('https://www.baidu.com', width = '100%', height = 350)
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="https://www.baidu.com"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 本地文件
# `from from IPython.display import FileLink, FileLinks`

# %% [markdown]
# ## JavaScript
# `from IPython.display import Javascript` OR `javascript`
# ## HTML
# `from IPython.display import HTML` OR `%%html`
# ## JSON
# ## Latax
# `from IPython.display import Latex` OR `from IPython.display import Math` OR `%%latex`

# %%
# %%latex
# \begin{equation}
#     Y = Y_0 M^{\frac{3}{4}}
# \end{equation}
# Out:
# \begin{equation}
#     Y = Y_0 M^{\frac{3}{4}}
# \end{equation}

# %% [markdown]
# ## 富文本与安全
